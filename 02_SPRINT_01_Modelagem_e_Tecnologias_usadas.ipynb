# %% [markdown]
# ##**SPRINT 01- OBJETIVOS**
#
# Nessa sprint de trabalho os principais objetivos foram:
#
# **01- Descrever o Problema de Negócio:**\
# Nesta etapa, houve uma análise e documentação detalhada do problema de negócios que o projeto estava resolvendo. Isso incluiu a compreensão dos requisitos, as necessidades dos stakeholders e uma clara definição do escopo do projeto.
#
# **02- Modelagem do Data Warehouse:**\
# A modelagem do data warehouse foi uma parte fundamental do projeto, onde foram projetadas as estruturas de armazenamento de dados, as tabelas, os relacionamentos e as dimensões necessárias para suportar as análises futuras. Essa etapa garantiu que o data warehouse fosse eficiente e atendesse às necessidades de análise de negócios.
#
# **03- Instalação das Tecnologias usadas no projetp:**\
# A instalação das tecnologias essenciais que seriam utilizadas no projeto ocorreu da seguinte maneira:
#
# * Foi configurado o banco de dados **PostgreSQL**;
# * O ambiente **Anaconda Python** para análise de dados foi instalado.
# * O **Apache Airflow** foi configurado para a orquestração de tarefas e fluxos de dados.
#
# Essas foram etapas cruciais para o início do projeto, pois estabeleceram as bases necessárias para a construção do **data warehouse** e a implementação das análises de dados. A partir dessas atividades, foi possível avançar nas próximas Sprints, desenvolvendo as soluções que dariam suporte à tomada de decisões com base nos dados.

# %% [markdown]
# ##**01-Descrevendo o Problema de Negócio**
#
#
# A **LOGSOLUTIONS** atua no setor de varejo, comercializando diversos produtos em várias lojas em todo o Brasil. A empresa desejava implementar um **Data Warehouse (DW)** para apoiar suas decisões de negócios. O foco foi na área de **logística**, que apresentava custos elevados nas entregas dos produtos.
#
# A empresa colaborou com diversas transportadoras que eram responsáveis por coletar produtos em diversos depósitos da empresa e realizar entregas aos clientes. Cada entrega variava de acordo com o produto e o local de entrega.
#
# A Organização buscou maneiras de compreender como reduzir os **custos de frete**. Além disso, a empresa desejou comparar o tempo necessário para cada transportadora concluir uma entrega. Isso envolveu medir a diferença entre a data de coleta do produto nos depósitos da empresa e a data de entrega ao cliente. Quando a transportadora coletou o produto e registrou a documentação, esse processo foi iniciado. A partir desse momento, o prazo começou a contar até que o produto fosse entregue ao cliente e assinado como recebido. Nesse ponto, considerou-se que o processo de entrega estava concluído.
#
# A **LOGSOLUTIONS** precisou medir essa diferença, pois foi solicitado um relatório que fornecesse essas informações. O cliente paga pelo frete em compras acima de R$ 100,00 , mas independentemente disso, cada transportadora recebeu pagamento pelo seu serviço. A empresa manteve registros dos clientes das transportadoras, dos depósitos, parceiros de entregas, dos custos de frete e do desempenho das transportadoras.
#
# ---
#
# ###**1.1-Solução para o problema de negócio**
#
#
# ![Captura de tela 2023-09-25 110859.png](data:image/png;base64,...)
#
#
# ---

# %% [markdown]
# Analisando as informações que estavam no problema de negócio, foi decidido criar um **Data Warehouse**, mais especificamente um **Data Mart**, voltado para uma área específica, nesse caso a área de **logística**. Esse Data Mart foi construído em cima do **PostgreSQL** e teve suas dimensões alimentadas por um pipeline de dados construído em **linguagem Python** com suporte do **Apache Airflow**, que agendamos para que assim que os arquivos gerados pelos sistemas transacionais fossem direcionados para uma pasta específica, com esses arquivos em pasta, o processo de extração, transformação e carga no **Data Warehouse** é executado.

# %% [markdown]
# ----

# %% [markdown]
# ##**02- Modelando o Data Warehouse**
#
# Com as informações do problema de negócio, foram identificadas sete dimensões que foram utilizadas na modelagem do Data Warehouse para a área de Logística da LogSolutions. Abaixo, estão as dimensões identificadas, juntamente com a justificativa para sua inclusão no Data Warehouse:
#
# **Dimensão Cliente:** Assume um papel central nesse contexto, uma vez que é o destinatário dos produtos. Além disso, as condições de pagamento do frete estão diretamente relacionadas ao valor da compra, e é o cliente quem valida a entrega. Por essas razões, a inclusão da dimensão Cliente se mostra essencial para o sucesso desse modelo.
#
# **Dimensão Transportadora:** Desempenha um papel crucial, sendo responsável por coletar os produtos nos depósitos da empresa. É importante ressaltar que a LOG.SOLUTIONS dispõe de informações detalhadas sobre as transportadoras, e cada uma delas pode adotar diferentes métodos de entrega, como o uso de caminhões ou serviços terceirizados. Vale destacar que o tipo de transporte escolhido também impacta diretamente nos custos associados, tornando essa dimensão de extrema relevância para o modelo em questão.
#
# **Dimensão Produto:** É essencial, uma vez que o tipo de produto tem uma influência direta no cálculo do preço do frete. Produtos de maior dimensão podem demandar métodos de entrega distintos em comparação aos produtos de menor porte, o que torna esta dimensão fundamental para o entendimento e a otimização do processo logístico.
#
# **Dimensão Tempo:** Permite a análise de datas de coleta e entrega, o cálculo dos tempos de entrega e a criação de relatórios relacionados às datas. Ela é essencial para acompanhar e otimizar o fluxo de tempo em todo o processo logístico.
#
# **Dimensão Depósito:** Possui um papel crítico no processo de entrega, exercendo influência significativa sobre a logística. Ela desempenha um papel fundamental ao afetar diversos aspectos da cadeia de suprimentos e da distribuição de produtos.
#
# **Dimensão Entrega:** Fundamental para monitorar a eficácia das entregas e a satisfação do cliente. Ela habilita a criação de relatórios específicos, proporcionando insights valiosos para compreender a ocorrência de atrasos nas entregas e outros problemas relacionados ao processo de entrega.
#
# **Dimensão Pagamento:** Registra os pagamentos de frete, tornando-se um elemento essencial para análises financeiras. Embora algumas medidas possam estar na tabela de fatos, esta dimensão oferece os atributos necessários para a elaboração de relatórios financeiros de relevância.

# %% [markdown]
# ---

# %% [markdown]
# ##**03- Modelo Star Schema**
# **Modelo Star Schema - LogSolution**

# %% [markdown]
# ![Captura de tela 2023-10-18 183510.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ##**04- Tecnologias do Projeto**
#
# As tecnologias usadas nesse projeto foram instaladas e configuradas:
#
# * **Docker**, Para criação de containers;
# * **PostgreSQL e PGadmin**, para criação do Data Warehouse do projeto;
# * **Anaconda Python**, para desenvolver scripts e tarefas personalizadas que serão executadas como parte de um DAG do Apache Airflow.
# * **Apache Airflow**, para automatizar tarefas, agendar pipelines de dados, realizar ETL de dados e integrar sistemas.
#
# ---

# %% [markdown]
# ###**4.1 - Instalação do Docker**
#
# As informações e detalhadas sobre como instalar o Docker foram encontradas no site oficial do Docker:
#
# https://docs.docker.com/get-docker/
#
# Nesse link, encontramos instruções para instalar o Docker em diferentes sistemas operacionais, como **Windows**, **macOS** e **Linux**.
#
# ---

# %% [markdown]
# ###**4.2- Instalação do Banco de dados**
#
# Um container **Docker** com um banco de dados PostgreSQL foi criado, configurando um nome de usuário. Além disso, a porta XXXX no host foi mapeada para a porta YYYY no contêiner, permitindo conexões ao banco de dados. O contêiner foi nomeado como **"logística"** para facilitar a referência futura.
#
# ```
# # Modelo do código do container com a imagem do Postgres
#
# docker run --name “nome do container” -p xxxx:yyyy -e POSTGRES_USER=nome do usuario
# -e POSTGRES_PASSWORD=senha -e POSTGRES_DB=nome do banco de addoss -d postgres
#
#
# ```
#
#
# Foram utilizados os links abaixo para copiar o comando para uso da imagem do PostgreSQL e seguir os passos para a criação e customização de containers.
#
# * https://www.docker.com
#
# * https://hub.docker.com/_/postgres
#
#
# Foram utilizados os links abaixo para downloads do pgadmim.
#
# * https://www.postgresql.org/
# * https://www.pgadmin.org/
#
# Processo executado via linha de comando no linux
#
# ---
#
# ###**4.3- Criando a conexão do Banco de Dados do Pgadmim com o container**
#
# Para Estabelecer esse conexão os seguintes passoas para seguidos;
#
# 01- Dentro do Pgadmim, clicar com o botão direito em **Server/Register/Server**
#
#
# ![image.png](data:image/png;base64,...)
#
#
# **02 e 03 - Configurar o Register/Server/General e Connection**
#
# **Register server/General** colocar:
# * Nome para o servidor
#
# **Register server/Connection**, colocar:
# * local host;
# * Porta:
# * Nome do Banco de Dados;
# * Nome do usúario;
# * Senha
#
# ![image.png](data:image/png;base64,...)
#
# **04 e 05 - Criar o Schema e as tabelas**
#
# Após as etapas 03 e 04, foi criado o banco de dados logsolutions, dentro o schema chamado **"varejo"** e foram criadas as tabelas
#
# ![image.png](data:image/png;base64,...)
#
# ---

# %% [markdown]
# ###**5.3- Códigos para criação da tabela Fato e Tabelas Dimensões**
#
# ```
# # 01- Criar tabela "DIM_CLIENTE"
#
# CREATE TABLE lab6.DIM_CLIENTE
# (
#     id_cliente int NOT NULL,
#     nome_cliente text,
#     sobrenome_cliente text,
#     PRIMARY KEY (id_cliente)
# );
#
# ```
# ```
# # 02-  Criar tabela "DIM_TRANSPORTADORA"
#
# CREATE TABLE varejo."DIM_TRANSPORTADORA"
# (
#     id_transportadora integer NOT NULL,
#     nome_transportadora text,
#     PRIMARY KEY (id_transportadora)
# );
#
# ```
# ```
# # 03-  Criar tabela "DIM_DEPOSITO"
#
# CREATE TABLE varejo."DIM_DEPOSITO"
# (
#     id_deposito bigint NOT NULL,
#     nome_deposito text,
#     PRIMARY KEY (id_deposito)
# );
#
# ```
# ```
# # 04-  Criar tabela "DIM_ENTREGA"
#
# REATE TABLE varejo."DIM_ENTREGA"
# (
#     id_entrega bigint NOT NULL,
#     endereco_entrega text,
#     pais_entrega text,
#     PRIMARY KEY (id_entrega)
# );
#
# ```
# ```
# # 05-  Criar tabela "DIM_PAGAMENTO"
#
# RCREATE TABLE varejo."DIM_PAGAMENTO"
# (
#     id_pagamento bigint NOT NULL,
#     tipo_pagamento text,
#     PRIMARY KEY (id_pagamento)
# );
#
# ```
# ```
# # 06-  Criar tabela "DIM_FRETE"
#
# CREATE TABLE varejo."DIM_FRETE"
# (
#     id_frete bigint NOT NULL,
#     tipo_frete text,
#     PRIMARY KEY (id_frete)
# );
#
# ```
# ```
# # 07-  Criar tabela "DIM_DATA"
#
# CREATE TABLE varejo."DIM_DATA"
# (
#     id_data bigint NOT NULL,
#     data_completa text,
#     dia integer,
#     mes integer,
#     ano integer,
#     PRIMARY KEY (id_data)
# );
# ```
# ```
# # 08-  Criar tabela "TB_FATO"
#
# CREATE TABLE varejo."TB_FATO"
# (
#     id_cliente integer,
#     id_transportadora integer,
#     id_deposito integer,
#     id_entrega integer,
#     id_pagamento integer,
#     id_frete integer,
#     id_data integer,
#     valor_entrega double precision,
#     PRIMARY KEY (id_cliente, id_transportadora,
#     id_deposito, id_entrega, id_pagamento, id_frete, id_data)
# );
# ```
#
#
#
#
# ---

# %% [markdown]
# **Comentando os código:**
#
# Os códigos acima criaram tabelas em um banco de dados, onde cada tabela representava uma dimensão ou uma tabela fato em um esquema de data warehouse para a área de logística da LogSolutions.
#
# Cada tabela tinha suas próprias colunas e uma chave primária que a identificava de forma exclusiva. As tabelas de dimensões armazenavam informações descritivas, enquanto a tabela de fato relacionava informações de diferentes dimensões. Essas tabelas foram parte fundamental da estrutura de armazenamento de dados para análise e relatórios na área de logística.

# %% [markdown]
# ---

# %% [markdown]
# ###**5.4- Instalando o Anaconda Python**
#
# Para Realizar o downloads do Anaconda Python foi seguida a documentação oficial:
#
# https://www.anaconda.com/download#downloads
#
# * Baixado o arquivo para uma pasta de acordo com seu sistema operacional;
#
# * Descompactado o arquivo no terminal linux com o comando abaixo.
#
# ```
# # bash Anaconda3-2023.07-2-Linux-x86_64.sh
# ```
# * seguir os passos que o sistema informa.
#
# ---

# %% [markdown]
# ##**5.5- Instação do Apache Airflow**
#
# O Apache Airflow foi instalado via docker;
#
# **A-** O primeiro passo foi criar uma pasta chamada "airflow" dentro do diretório principal.
#
# **/ home/mvslopes/airflow**

# %% [markdown]
# ---

# %% [markdown]
# **B-** Após criar a estrutura de pastas que receberá o Apache Airflow, foi realizada a consulta à documentação oficial em:
# https://airflow.apache.org/docs/apache-airflow/stable/howto/docker-compose/index.html
#
# Seguindo a documentação para realizar o download do Apache Airflow via Docker, o primeiro comando que executamos no sistema Linux foi:
#
#
# ```
# curl -LfO 'https://airflow.apache.org/docs/apache-airflow/2.7.1/docker-compose.yaml'
# ```
#
# Este comando contém os detalhes para a criação dos contêineres, que serão oito. Deve ser executado dentro da pasta que foi criada:
#
# **/ home/mvslopes/airflow para realizar o downloads.**

# %% [markdown]
# ---

# %% [markdown]
# **C-** Seguindo a Documentação do Airflow, é necessário criar três pastas:
#
# **Comando para criação das pastas**
#
#
# ```
# mkdir -p ./dags ./logs ./plugins ./config
# ```
#
#
#
#
# **dags:** Esta pasta é usada para armazenar as DAGs (Directed Acyclic Graphs), que são os arquivos de definição de tarefas e fluxos de trabalho no Airflow.
#
# **logs:** Aqui você pode armazenar os registros (logs) das execuções das tarefas e dos DAGs.
#
# **plugins:** Esta pasta é usada para armazenar seus plugins personalizados, que podem conter operadores, sensores e ganchos personalizados para estender as funcionalidades do Airflow.

# %% [markdown]
# ---

# %% [markdown]
# **D-** A documentação solicita que ajuste uma variável de ambiente.
#
# **Comando para Ajuste de variavel de ambiente**
#
#
# ```
# echo -e "AIRFLOW_UID=$(id -u)" > .env
# ```

# %% [markdown]
# ---

# %% [markdown]
# **E-** Inicializar o banco de dados do Airflow.
#
# **comando para iniciar o banco de dados Airflow**
# ```
# docker compose up airflow-init
# ```

# %% [markdown]
# ---

# %% [markdown]
# **F-** Inicializar o Apache Airflow.
#
# **Comando para inicializar o Airflow**
#
#
# ```
# docker compose up
# ```

# %% [markdown]
# ---

# %% [markdown]
# ###**5.6- Interface do Apache Airflow**
#
# Após a inicialização do apache Airflow com o comando:
#
#
#
# ```
# docker compose up
#
# ```
#
# Vamos iniciar a interface do Apache Airflow através do navegador digiltando:
#
# ```
# Localhost:8080
#
# ```
#
# **Teremos as Interfaces abixo**\
#  **01- Solicitando loging e senha**
#
# ![interface airflow.png](data:image/png;base64,...)
#
#  **02- Interface Apache Airflow**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**SRPINT 01 FINALIZADA**
#
# **Os objetivos da Sprint 01 foram alcançados:**
#
# * Descrever o Problema de Negócio - Realizado
# * Modelar o Data Warehouse - Realizado
# * Instalar as Tecnologias - Realizado
#
# Isso demonstra que as principais metas da primeira sprint foram concluídas com sucesso.
